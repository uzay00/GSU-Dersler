# %% [markdown]
# https://mertmekatronik.com/turkce-speech-recognition
#
#
# >  Konuşma tanıma konusunda ücretli Google Speech Recognition API servisine nazaran ücretsizdir. Ama bir dezavantajı ise gerçek zamanlı kelimeleri yazıya çeviremez yapamaz. Bir konuşmayı algılaması için sizin cümleyi bitirmeniz beklenir ve kaydedilen ses dosyasını ücretsiz Google sunucularına yollanarak geri dönüş alınır.

# %%
#!brew install portaudio
#!pip install pyaudio
#!pip install SpeechRecognition

# %%
import speech_recognition as sr
mic = sr.Microphone()
r = sr.Recognizer()

# %%
with sr.Microphone() as source:
    r.adjust_for_ambient_noise(source)
    print("Arka plan gürültüsü:" + str(r.energy_threshold))

    try:
        print("Dinliyorum: ")
        ses = r.listen(source, timeout=2, phrase_time_limit=5)
        print(r.recognize_google(ses, language='tr-tr'))
    except sr.WaitTimeoutError:
        print("Dinleme zaman aşımına uğradı")

    except sr.UnknownValueError:
        print("Ne dediğini anlayamadım")

    except sr.RequestError:
        print("İnternete bağlanamıyorum")
# Out:
# Arka plan gürültüsü:53.05598868802567
# Dinliyorum:
# Merhaba arıza kaydı 76 ile ile ilgili konuşuyorum

# %%
with sr.Microphone() as source:
    try:
        print("Dinliyorum: ")
        ses = r.listen(source, timeout=2, phrase_time_limit=5)
        print(r.recognize_google(ses, language='tr-tr'))
    except sr.WaitTimeoutError:
        print("Dinleme zaman aşımına uğradı")

    except sr.UnknownValueError:
        print("Ne dediğini anlayamadım")

    except sr.RequestError:
        print("İnternete bağlanamıyorum")

# %% [markdown]
# https://realpython.com/python-speech-recognition/

# %%
def recognize_speech_from_mic(recognizer, microphone, firsttime = False):
    """Transcribe speech from recorded from `microphone`.

    Returns a dictionary with three keys:
    "success": a boolean indicating whether or not the API request was
               successful
    "error":   `None` if no error occured, otherwise a string containing
               an error message if the API could not be reached or
               speech was unrecognizable
    "transcription": `None` if speech could not be transcribed,
               otherwise a string containing the transcribed text
    """
    # check that recognizer and microphone arguments are appropriate type
    if not isinstance(recognizer, sr.Recognizer):
        raise TypeError("`recognizer` must be `Recognizer` instance")

    if not isinstance(microphone, sr.Microphone):
        raise TypeError("`microphone` must be `Microphone` instance")

    # adjust the recognizer sensitivity to ambient noise and record audio
    # from the microphone
    with microphone as source:
        if firsttime == True:
            recognizer.adjust_for_ambient_noise(source)
        print('recording..')
        audio = recognizer.listen(source)

    # set up the response object
    response = {
        "success": True,
        "error": None,
        "transcription": None
    }

    # try recognizing the speech in the recording
    # if a RequestError or UnknownValueError exception is caught,
    #     update the response object accordingly
    try:
        response["transcription"] = recognizer.recognize_google(audio, language='tr-tr')
    except sr.RequestError:
        # API was unreachable or unresponsive
        response["success"] = False
        response["error"] = "API unavailable"
    except sr.UnknownValueError:
        # speech was unintelligible
        response["error"] = "Unable to recognize speech"

    return response

# %%
guess = recognize_speech_from_mic(r, mic, firsttime = True)
# Out:
# recording..

# %%
guess
# Out:
# {'success': True,
#  'error': None,
#  'transcription': 'kurye çok geç geldi yemek soğuktu'}

# %%
guess = recognize_speech_from_mic(r, mic)

# %%
guess['transcription']
# Out:
# 'kurye çok geç geldi yemek soğuktu'

# %%
#!pip install sumapi

# %%
from sumapi.api import SumAPI

api = SumAPI(username='xxxxxxxxxx', password='xxxxxxxxxx')

# %%
api.sentiment_analysis('Bu harika bir filmdi.', domain='general')
# Out:
# {'body': 'Bu harika bir filmdi.',
#  'evaluation': {'label': 'positive', 'score': 0.9839390516281128}}

# %%
guess['transcription']
# Out:
# 'kurye çok geç geldi yemek soğuktu'

# %%
api.sentiment_analysis(guess['transcription'], domain='general')

# %%
def cagri():
    guess = recognize_speech_from_mic(r, mic)
    transcription = guess['transcription']
    print(transcription)
    analysis = api.sentiment_analysis(transcription, domain='general')
    return analysis['evaluation']

# %%
cagri()
# Out:
# recording..
# internetin çekmemesi çok kötü
# {'label': 'negative', 'score': 0.9992506504058838}

# %%
cagri()

# %%
cagri()

# %%
api.zero_shot_classification('Bu nasıl bir hizmet, gerçekten rezilsiniz.', categories='talep,şikayet,öneri')
# Out:
# {'body': 'Bu nasıl bir hizmet, gerçekten rezilsiniz.',
#  'evaluation': {'sequence': 'Bu nasıl bir hizmet, gerçekten rezilsiniz.',
#   'labels': ['şikayet', 'öneri', 'talep'],
#   'scores': [0.97139573097229, 0.820141077041626, 0.589176595211029],
#   'label': 'şikayet'}}

# %%
api.zero_shot_classification('Mac book pro super bir GPU sahip', 
                             categories='teknoloji, spor, ekonomi')
# Out:
# {'body': 'Mac book pro super bir GPU sahip',
#  'evaluation': {'sequence': 'Mac book pro super bir GPU sahip',
#   'labels': ['teknoloji', ' spor', ' ekonomi'],
#   'scores': [0.9906918406486511, 0.9401687979698181, 0.02984868735074997],
#   'label': 'teknoloji'}}

# %%
api.zero_shot_classification('Yelken kullan', 
                             categories='teknoloji, spor, ekonomi')
# Out:
# {'body': 'Yelken kullan',
#  'evaluation': {'sequence': 'Yelken kullan',
#   'labels': [' spor', 'teknoloji', ' ekonomi'],
#   'scores': [0.6545960307121277, 0.3135998845100403, 0.15357674658298492],
#   'label': ' spor'}}

# %% [markdown]
# Hata duzeltme https://pypi.org/project/turkishnlp/

# %%
# !pip install turkishnlp

# %%
from turkishnlp import detector
obj = detector.TurkishNLP()

# %%
obj.download()

# %%
obj.create_word_set()

# %%
lwords = obj.list_words("vri kümsi idrae edre ancakadaha güezl oaflbiler")
print(obj.auto_correct(lwords))

# %%
obj.correct_text_without_space('türkçedoğaldilişleme')
